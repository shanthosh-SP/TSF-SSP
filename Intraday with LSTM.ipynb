# %% [markdown]
# <a href="https://colab.research.google.com/github/shanthosh-SP/TSF-SSP/blob/main/Intraday%20with%20LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensorflow with GPU
#
# This notebook provides an introduction to computing on a [GPU](https://cloud.google.com/gpu) in Colab. In this notebook you will connect to a GPU, and then run some basic TensorFlow operations on both the CPU and a GPU, observing the speedup provided by using the GPU.

# %% [markdown]
# ## Enabling and testing the GPU
#
# First, you'll need to enable GPUs for the notebook:
#
# - Navigate to Edit→Notebook Settings
# - select GPU from the Hardware Accelerator drop-down
#
# Next, we'll confirm that we can connect to the GPU with tensorflow:

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# ## Observe TensorFlow speedup on GPU relative to CPU
#
# This example constructs a typical convolutional neural network layer over a
# random image and manually places the resulting ops on either the CPU or the GPU
# to compare execution speed.

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.8373299170000337
# GPU (s):
# 0.0404377669999576
# GPU speedup over CPU: 94x

# %%
## LSTM For Historical Dataset, Chosing Targeting value as Augumented Feature Exponential  Moving Average 

import pandas as pd
df=pd.read_excel('/content/history.xlsx')
df.head()

##prediction on close
df1=df.reset_index()['EMA']
df1.shape

import matplotlib.pyplot as plt
plt.plot(df1)

import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

df1.shape

##Spliting train test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]
print(training_size)
print(test_size)
print(df1.shape)

##convert an array of values into a dataset matrix
import numpy
def create_dataset(dataset,time_step=1):
	dataX,dataY=[],[]
	for i in range(len(dataset)-time_step-1):
		a=dataset[i:(i+time_step),0]
		dataX.append(a)
		dataY.append(dataset[i+time_step,0])
	return numpy.array(dataX),numpy.array(dataY)

##reshape into X=t,t+1,t+2,t+3 and t+4
time_step=100
X_train,y_train=create_dataset(train_data,time_step)
X_test,y_test=create_dataset(test_data,time_step)
 

#reshape input to be [samples,time steps,features] which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

##create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()

model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)


import tensorflow as tf

tf.__version__

##Lets Do the Prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

##transform to orginal form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

##calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
print(math.sqrt(mean_squared_error(y_train,train_predict)))
print(math.sqrt(mean_squared_error(y_test,test_predict)))

##Plotting
##shift train predictions for plotting
look_back=100
trainPredictPlot=numpy.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict

##shift test predictions for plotting
testPredictPlot =numpy.empty_like(df1)
testPredictPlot[:,:]=numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict

##plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 5757
# 3100
# (8857, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 89/89 [==============================] - 14s 93ms/step - loss: 8.3822e-04 - val_loss: 4.2255e-04
# Epoch 2/100
# 89/89 [==============================] - 7s 80ms/step - loss: 7.5672e-07 - val_loss: 0.0012
# Epoch 3/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.1620e-07 - val_loss: 0.0016
# Epoch 4/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.5089e-07 - val_loss: 0.0017
# Epoch 5/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.7861e-07 - val_loss: 0.0017
# Epoch 6/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.4712e-07 - val_loss: 0.0017
# Epoch 7/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.7313e-07 - val_loss: 0.0017
# Epoch 8/100
# 89/89 [==============================] - 7s 79ms/step - loss: 2.5966e-07 - val_loss: 0.0018
# Epoch 9/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.8444e-07 - val_loss: 0.0017
# Epoch 10/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.0290e-07 - val_loss: 0.0016
# Epoch 11/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.6061e-07 - val_loss: 0.0016
# Epoch 12/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.9156e-07 - val_loss: 0.0016
# Epoch 13/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.5834e-07 - val_loss: 0.0016
# Epoch 14/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.1486e-07 - val_loss: 0.0016
# Epoch 15/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.9499e-07 - val_loss: 0.0015
# Epoch 16/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.0069e-07 - val_loss: 0.0014
# Epoch 17/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.4549e-07 - val_loss: 0.0016
# Epoch 18/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.4037e-07 - val_loss: 0.0015
# Epoch 19/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.5902e-07 - val_loss: 0.0014
# Epoch 20/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.6871e-07 - val_loss: 0.0015
# Epoch 21/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.7702e-07 - val_loss: 0.0014
# Epoch 22/100
# 89/89 [==============================] - 7s 80ms/step - loss: 4.2920e-07 - val_loss: 0.0013
# Epoch 23/100
# 89/89 [==============================] - 7s 80ms/step - loss: 6.6120e-07 - val_loss: 0.0013
# Epoch 24/100
# 89/89 [==============================] - 7s 81ms/step - loss: 6.2613e-07 - val_loss: 0.0014
# Epoch 25/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.7489e-07 - val_loss: 0.0013
# Epoch 26/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.7669e-07 - val_loss: 0.0013
# Epoch 27/100
# 89/89 [==============================] - 7s 80ms/step - loss: 9.1730e-07 - val_loss: 0.0015
# Epoch 28/100
# 89/89 [==============================] - 7s 80ms/step - loss: 8.4034e-07 - val_loss: 0.0011
# Epoch 29/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.0543e-06 - val_loss: 0.0013
# Epoch 30/100
# 89/89 [==============================] - 7s 81ms/step - loss: 6.6155e-07 - val_loss: 0.0014
# Epoch 31/100
# 89/89 [==============================] - 7s 81ms/step - loss: 7.6789e-06 - val_loss: 0.0012
# Epoch 32/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.1404e-07 - val_loss: 0.0011
# Epoch 33/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.9993e-07 - val_loss: 0.0011
# Epoch 34/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.4206e-07 - val_loss: 0.0010
# Epoch 35/100
# 89/89 [==============================] - 7s 81ms/step - loss: 7.6688e-07 - val_loss: 0.0010
# Epoch 36/100
# 89/89 [==============================] - 7s 80ms/step - loss: 7.7093e-07 - val_loss: 9.9379e-04
# Epoch 37/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.8482e-06 - val_loss: 9.7301e-04
# Epoch 38/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.3537e-06 - val_loss: 0.0011
# Epoch 39/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.9587e-06 - val_loss: 0.0011
# Epoch 40/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.7246e-07 - val_loss: 0.0011
# Epoch 41/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.7904e-07 - val_loss: 9.1141e-04
# Epoch 42/100
# 89/89 [==============================] - 7s 82ms/step - loss: 6.6599e-07 - val_loss: 0.0011
# Epoch 43/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.1901e-06 - val_loss: 9.0587e-04
# Epoch 44/100
# 89/89 [==============================] - 7s 81ms/step - loss: 8.1444e-07 - val_loss: 0.0011
# Epoch 45/100
# 89/89 [==============================] - 7s 81ms/step - loss: 7.8671e-06 - val_loss: 9.0225e-04
# Epoch 46/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.7268e-07 - val_loss: 7.7816e-04
# Epoch 47/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.5465e-07 - val_loss: 7.8370e-04
# Epoch 48/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.0681e-06 - val_loss: 8.5816e-04
# Epoch 49/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.2109e-07 - val_loss: 7.1876e-04
# Epoch 50/100
# 89/89 [==============================] - 7s 80ms/step - loss: 7.8963e-07 - val_loss: 7.9304e-04
# Epoch 51/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.9147e-07 - val_loss: 5.7483e-04
# Epoch 52/100
# 89/89 [==============================] - 7s 80ms/step - loss: 7.6368e-07 - val_loss: 6.4471e-04
# Epoch 53/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.3987e-06 - val_loss: 7.6916e-04
# Epoch 54/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.4338e-07 - val_loss: 6.5929e-04
# Epoch 55/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.6078e-07 - val_loss: 6.8379e-04
# Epoch 56/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.5534e-06 - val_loss: 5.1021e-04
# Epoch 57/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.6158e-06 - val_loss: 4.6423e-04
# Epoch 58/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.1273e-06 - val_loss: 5.5655e-04
# Epoch 59/100
# 89/89 [==============================] - 7s 80ms/step - loss: 6.3409e-07 - val_loss: 5.2777e-04
# Epoch 60/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.3797e-07 - val_loss: 5.2988e-04
# Epoch 61/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.1063e-06 - val_loss: 2.3775e-04
# Epoch 62/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.6666e-06 - val_loss: 5.6694e-04
# Epoch 63/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.4312e-07 - val_loss: 4.9782e-04
# Epoch 64/100
# 89/89 [==============================] - 7s 80ms/step - loss: 3.9535e-07 - val_loss: 5.6632e-04
# Epoch 65/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.4161e-07 - val_loss: 4.2592e-04
# Epoch 66/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.7489e-07 - val_loss: 4.0298e-04
# Epoch 67/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.0947e-07 - val_loss: 3.9489e-04
# Epoch 68/100
# 89/89 [==============================] - 7s 82ms/step - loss: 6.8715e-07 - val_loss: 4.9325e-04
# Epoch 69/100
# 89/89 [==============================] - 7s 81ms/step - loss: 9.7164e-07 - val_loss: 4.3558e-04
# Epoch 70/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.7176e-07 - val_loss: 3.1465e-04
# Epoch 71/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.2950e-06 - val_loss: 3.0471e-04
# Epoch 72/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.9815e-07 - val_loss: 3.0192e-04
# Epoch 73/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.0403e-07 - val_loss: 2.5254e-04
# Epoch 74/100
# 89/89 [==============================] - 7s 82ms/step - loss: 8.0996e-06 - val_loss: 3.0860e-04
# Epoch 75/100
# 89/89 [==============================] - 7s 82ms/step - loss: 7.0308e-07 - val_loss: 3.0850e-04
# Epoch 76/100
# 89/89 [==============================] - 7s 82ms/step - loss: 2.3515e-07 - val_loss: 2.4855e-04
# Epoch 77/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.7248e-07 - val_loss: 2.3667e-04
# Epoch 78/100
# 89/89 [==============================] - 7s 82ms/step - loss: 8.7269e-08 - val_loss: 1.9855e-04
# Epoch 79/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.8800e-07 - val_loss: 1.7911e-04
# Epoch 80/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.0634e-07 - val_loss: 1.5844e-04
# Epoch 81/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.2792e-06 - val_loss: 1.4359e-04
# Epoch 82/100
# 89/89 [==============================] - 7s 82ms/step - loss: 5.2865e-07 - val_loss: 1.7136e-04
# Epoch 83/100
# 89/89 [==============================] - 7s 81ms/step - loss: 6.3999e-06 - val_loss: 1.0885e-04
# Epoch 84/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.3502e-07 - val_loss: 1.9643e-04
# Epoch 85/100
# 89/89 [==============================] - 7s 81ms/step - loss: 9.7533e-08 - val_loss: 1.7926e-04
# Epoch 86/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.3956e-07 - val_loss: 1.2121e-04
# Epoch 87/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.4230e-07 - val_loss: 9.0550e-05
# Epoch 88/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.9355e-07 - val_loss: 9.8257e-05
# Epoch 89/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.5842e-07 - val_loss: 8.5623e-05
# Epoch 90/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.9605e-07 - val_loss: 2.9449e-05
# Epoch 91/100
# 89/89 [==============================] - 7s 82ms/step - loss: 3.4331e-07 - val_loss: 2.8319e-05
# Epoch 92/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.2410e-06 - val_loss: 1.5325e-04
# Epoch 93/100
# 89/89 [==============================] - 7s 81ms/step - loss: 6.3781e-06 - val_loss: 1.4183e-04
# Epoch 94/100
# 89/89 [==============================] - 7s 81ms/step - loss: 6.5317e-08 - val_loss: 1.0659e-04
# Epoch 95/100
# 89/89 [==============================] - 7s 81ms/step - loss: 5.4534e-08 - val_loss: 8.3334e-05
# Epoch 96/100
# 89/89 [==============================] - 7s 80ms/step - loss: 9.8677e-08 - val_loss: 6.0141e-05
# Epoch 97/100
# 89/89 [==============================] - 7s 81ms/step - loss: 8.1500e-08 - val_loss: 3.7410e-05
# Epoch 98/100
# 89/89 [==============================] - 7s 80ms/step - loss: 7.7003e-08 - val_loss: 2.5855e-05
# Epoch 99/100
# 89/89 [==============================] - 7s 80ms/step - loss: 8.8682e-08 - val_loss: 2.4823e-05
# Epoch 100/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.1470e-07 - val_loss: 9.0063e-06
# 6.995774435325812
# 23.81143565757706

# %%
## The Targeted value of Historical dataset is Closing price

import pandas as pd
df=pd.read_excel('/content/history.xlsx')
df.head()

##prediction on close
df1=df.reset_index()["Close"]
df1.shape

import matplotlib.pyplot as plt
plt.plot(df1)


import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

df1.shape

##Spliting train test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]
print(training_size)
print(test_size)
print(df1.shape)

##convert an array of values into a dataset matrix
import numpy
def create_dataset(dataset,time_step=1):
	dataX,dataY=[],[]
	for i in range(len(dataset)-time_step-1):
		a=dataset[i:(i+time_step),0]
		dataX.append(a)
		dataY.append(dataset[i+time_step,0])
	return numpy.array(dataX),numpy.array(dataY)

##reshape into X=t,t+1,t+2,t+3 and t+4
time_step=100
X_train,y_train=create_dataset(train_data,time_step)
X_test,y_test=create_dataset(test_data,time_step)
 

#reshape input to be [samples,time steps,features] which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

##create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()

model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)


import tensorflow as tf

tf.__version__

##Lets Do the Prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

##transform to orginal form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

##calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
print(math.sqrt(mean_squared_error(y_train,train_predict)))
print(math.sqrt(mean_squared_error(y_test,test_predict)))

##Plotting
##shift train predictions for plotting
look_back=100
trainPredictPlot=numpy.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict

##shift test predictions for plotting
testPredictPlot =numpy.empty_like(df1)
testPredictPlot[:,:]=numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict

##plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 5757
# 3100
# (8857, 1)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 89/89 [==============================] - 13s 96ms/step - loss: 2.6268e-04 - val_loss: 8.0300e-04
# Epoch 2/100
# 89/89 [==============================] - 7s 81ms/step - loss: 3.0519e-05 - val_loss: 0.0014
# Epoch 3/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.7986e-05 - val_loss: 0.0021
# Epoch 4/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.5985e-05 - val_loss: 0.0018
# Epoch 5/100
# 89/89 [==============================] - 7s 82ms/step - loss: 2.4453e-05 - val_loss: 0.0021
# Epoch 6/100
# 89/89 [==============================] - 7s 80ms/step - loss: 2.0441e-05 - val_loss: 0.0029
# Epoch 7/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.4977e-05 - val_loss: 0.0016
# Epoch 8/100
# 89/89 [==============================] - 7s 81ms/step - loss: 2.0282e-05 - val_loss: 0.0019
# Epoch 9/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.7456e-05 - val_loss: 0.0019
# Epoch 10/100
# 89/89 [==============================] - 7s 82ms/step - loss: 1.6673e-05 - val_loss: 0.0021
# Epoch 11/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.7826e-05 - val_loss: 0.0015
# Epoch 12/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.4812e-05 - val_loss: 0.0016
# Epoch 13/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.4252e-05 - val_loss: 0.0020
# Epoch 14/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.5111e-05 - val_loss: 0.0015
# Epoch 15/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.5123e-05 - val_loss: 0.0014
# Epoch 16/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.4559e-05 - val_loss: 0.0013
# Epoch 17/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.4729e-05 - val_loss: 0.0013
# Epoch 18/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.3515e-05 - val_loss: 0.0014
# Epoch 19/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.2390e-05 - val_loss: 8.3306e-04
# Epoch 20/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.1778e-05 - val_loss: 9.5807e-04
# Epoch 21/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.1539e-05 - val_loss: 9.3602e-04
# Epoch 22/100
# 89/89 [==============================] - 7s 81ms/step - loss: 1.3518e-05 - val_loss: 5.8561e-04
# Epoch 23/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1.4758e-05 - val_loss: 6.2014e-04
# Epoch 24/100
# 89/89 [==============================] - 7s 80ms/step - loss: 1
100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.6411e-06 - val_loss: 3.2820e-04
# Epoch 97/100
# 89/89 [==============================] - 7s 82ms/step - loss: 4.5414e-06 - val_loss: 4.0436e-04
# Epoch 98/100
# 89/89 [==============================] - 7s 81ms/step - loss: 4.4134e-06 - val_loss: 4.7230e-04
# Epoch 99/100
# 89/89 [==============================] - 7s 82ms/step - loss: 4.4558e-06 - val_loss: 3.8248e-04
# Epoch 100/100
# 89/89 [==============================] - 7s 82ms/step - loss: 4.6638e-06 - val_loss: 5.0390e-04
# 21.57895681351451
# 86.45076513115959

# %%
## Considering the Monthly dataset, Selecting the Targeting value as Augumeted feature Simple moving Average

import pandas as pd
df=pd.read_excel('/content/monthly.xlsx')
df.head()

##prediction on close
df1=df.reset_index()['SMA']
df1.shape

import matplotlib.pyplot as plt
plt.plot(df1)


import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

df1.shape

##Spliting train test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]
print(training_size)
print(test_size)

##convert an array of values into a dataset matrix
import numpy
def create_dataset(dataset,time_step=1):
	dataX,dataY=[],[]
	for i in range(len(dataset)-time_step-1):
		a=dataset[i:(i+time_step),0]
		dataX.append(a)
		dataY.append(dataset[i+time_step,0])
	return numpy.array(dataX),numpy.array(dataY)

##reshape into X=t,t+1,t+2,t+3 and t+4
time_step=100
X_train,y_train=create_dataset(train_data,time_step)
X_test,y_test=create_dataset(test_data,time_step)
 

#reshape input to be [samples,time steps,features] which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

##create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()

model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)


import tensorflow as tf

tf.__version__

##Lets Do the Prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

##transform to orginal form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

##calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
print(math.sqrt(mean_squared_error(y_train,train_predict)))
print(math.sqrt(mean_squared_error(y_test,test_predict)))

##Plotting
##shift train predictions for plotting
look_back=100
trainPredictPlot=numpy.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict

##shift test predictions for plotting
testPredictPlot =numpy.empty_like(df1)
testPredictPlot[:,:]=numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict

##plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# 14776
# 7957
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 230/230 [==============================] - 24s 85ms/step - loss: 0.0062 - val_loss: 2.1674e-04
# Epoch 2/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.0337e-04 - val_loss: 2.6791e-04
# Epoch 3/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.9147e-04 - val_loss: 2.9857e-04
# Epoch 4/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.7845e-04 - val_loss: 1.6962e-04
# Epoch 5/100
# 230/230 [==============================] - 18s 79ms/step - loss: 1.6906e-04 - val_loss: 1.5650e-04
# Epoch 6/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.5191e-04 - val_loss: 1.6965e-04
# Epoch 7/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.3514e-04 - val_loss: 1.2226e-04
# Epoch 8/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.6436e-04 - val_loss: 1.1854e-04
# Epoch 9/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.2024e-04 - val_loss: 9.3689e-05
# Epoch 10/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.1781e-04 - val_loss: 1.0135e-04
# Epoch 11/100
# 230/230 [==============================] - 18s 80ms/step - loss: 9.7932e-05 - val_loss: 1.4714e-04
# Epoch 12/100
# 230/230 [==============================] - 19s 81ms/step - loss: 8.9600e-05 - val_loss: 7.5918e-05
# Epoch 13/100
# 230/230 [==============================] - 19s 81ms/step - loss: 8.4220e-05 - val_loss: 1.6019e-04
# Epoch 14/100
# 230/230 [==============================] - 19s 81ms/step - loss: 7.6515e-05 - val_loss: 7.1283e-05
# Epoch 15/100
# 230/230 [==============================] - 18s 80ms/step - loss: 7.7580e-05 - val_loss: 6.1377e-05
# Epoch 16/100
# 230/230 [==============================] - 19s 81ms/step - loss: 6.1101e-05 - val_loss: 5.4771e-05
# Epoch 17/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.3851e-05 - val_loss: 1.2731e-04
# Epoch 18/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.9497e-05 - val_loss: 9.5465e-05
# Epoch 19/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5
100
# 230/230 [==============================] - 19s 81ms/step - loss: 6.7887e-06 - val_loss: 4.3042e-06
# Epoch 98/100
# 230/230 [==============================] - 19s 81ms/step - loss: 6.6964e-06 - val_loss: 2.1816e-06
# Epoch 99/100
# 230/230 [==============================] - 19s 81ms/step - loss: 6.6819e-06 - val_loss: 1.9111e-06
# Epoch 100/100
# 230/230 [==============================] - 19s 81ms/step - loss: 4.9887e-06 - val_loss: 3.4742e-06
# 14639.98093759424
# 14845.654779172397

# %%
## Considering the Targeted Feature as Closing price of Monthly dataset

import pandas as pd
df=pd.read_excel('/content/monthly.xlsx')
df.head()

##prediction on close
df1=df.reset_index()['close']
df1.shape

import matplotlib.pyplot as plt
plt.plot(df1)


import numpy as np
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

df1.shape

##Spliting train test split
training_size=int(len(df1)*0.65)
test_size=len(df1)-training_size
train_data,test_data=df1[0:training_size,:],df1[training_size:len(df1),:1]


##convert an array of values into a dataset matrix
import numpy
def create_dataset(dataset,time_step=1):
	dataX,dataY=[],[]
	for i in range(len(dataset)-time_step-1):
		a=dataset[i:(i+time_step),0]
		dataX.append(a)
		dataY.append(dataset[i+time_step,0])
	return numpy.array(dataX),numpy.array(dataY)

##reshape into X=t,t+1,t+2,t+3 and t+4
time_step=100
X_train,y_train=create_dataset(train_data,time_step)
X_test,y_test=create_dataset(test_data,time_step)
 

#reshape input to be [samples,time steps,features] which is required for LSTM
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],1)
X_test=X_test.reshape(X_test.shape[0],X_test.shape[1],1)

##create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.summary()

model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)


import tensorflow as tf

tf.__version__

##Lets Do the Prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

##transform to orginal form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

##calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
print(math.sqrt(mean_squared_error(y_train,train_predict)))
print(math.sqrt(mean_squared_error(y_test,test_predict)))

##Plotting
##shift train predictions for plotting
look_back=100
trainPredictPlot=numpy.empty_like(df1)
trainPredictPlot[:,:]=np.nan
trainPredictPlot[look_back:len(train_predict)+look_back,:]=train_predict

##shift test predictions for plotting
testPredictPlot =numpy.empty_like(df1)
testPredictPlot[:,:]=numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1,:]=test_predict

##plot baseline and predictions
plt.figure(figsize=(20,10))
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_9 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 50)           20200
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 230/230 [==============================] - 24s 85ms/step - loss: 0.0060 - val_loss: 2.4231e-04
# Epoch 2/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.1927e-04 - val_loss: 2.2255e-04
# Epoch 3/100
# 230/230 [==============================] - 18s 79ms/step - loss: 2.1248e-04 - val_loss: 3.3786e-04
# Epoch 4/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.0683e-04 - val_loss: 2.1274e-04
# Epoch 5/100
# 230/230 [==============================] - 18s 79ms/step - loss: 1.8132e-04 - val_loss: 1.6818e-04
# Epoch 6/100
# 230/230 [==============================] - 18s 79ms/step - loss: 1.7755e-04 - val_loss: 1.7342e-04
# Epoch 7/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.6476e-04 - val_loss: 3.3758e-04
# Epoch 8/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.4428e-04 - val_loss: 2.3224e-04
# Epoch 9/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.4317e-04 - val_loss: 2.3278e-04
# Epoch 10/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.3342e-04 - val_loss: 1.4724e-04
# Epoch 11/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.2457e-04 - val_loss: 1.3422e-04
# Epoch 12/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.2181e-04 - val_loss: 1.5923e-04
# Epoch 13/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.0840e-04 - val_loss: 1.8416e-04
# Epoch 14/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.0538e-04 - val_loss: 1.3050e-04
# Epoch 15/100
# 230/230 [==============================] - 18s 80ms/step - loss: 1.0479e-04 - val_loss: 2.5527e-04
# Epoch 16/100
# 230/230 [==============================] - 18s 80ms/step - loss: 9.3929e-05 - val_loss: 9.0259e-05
# Epoch 17/100
# 230/230 [==============================] - 18s 79ms/step - loss: 9.4729e-05 - val_loss: 1.1077e-04
# Epoch 18/100
# 230/230 [==============================] - 18s 80ms/step - loss: 8.5415e-05 - val_loss: 8.9086e-05
# Epoch 19/100
# 230/230 [==============================] - 18s 80ms/step - loss: 7.9480e-05 - val_loss: 6.2890e-05
# Epoch 20/100
# 230/230 [==============================] - 18s 80ms/step - loss: 6.7088e-05 - val_loss: 6.0741e-05
# Epoch 21/100
# 230/230 [==============================] - 18s 80ms/step - loss: 6.6435e-05 - val_loss: 6.9171e-05
# Epoch 22/100
# 230/230 [==============================] - 18s 80ms/step - loss: 6.8966e-05 - val_loss: 4.9112e-05
# Epoch 23/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.5957e-05 - val_loss: 8.8560e-05
# Epoch 24/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.1711e-05 - val_loss: 9.5621e-05
# Epoch 25/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.9118e-05 - val_loss: 6.6821e-05
# Epoch 26/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.5709e-05 - val_loss: 6.8452e-05
# Epoch 27/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.4604e-05 - val_loss: 3.5828e-05
# Epoch 28/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.6463e-05 - val_loss: 8.2438e-05
# Epoch 29/100
# 230/230 [==============================] - 18s 80ms/step - loss: 5.1296e-05 - val_loss: 8.7239e-05
# Epoch 30/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.0773e-05 - val_loss: 4.2256e-05
# Epoch 31/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.0723e-05 - val_loss: 3.1602e-05
# Epoch 32/100
# 230/230 [==============================] - 18s 80ms/step - loss: 4.5897e-05 - val_loss: 3.4302e-05
# Epoch 33/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.5073e-05 - val_loss: 3.1396e-05
# Epoch 34/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.6451e-05 - val_loss: 1.0070e-04
# Epoch 35/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.9441e-05 - val_loss: 2.7511e-05
# Epoch 36/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.8443e-05 - val_loss: 2.6838e-05
# Epoch 37/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.1981e-05 - val_loss: 3.0754e-05
# Epoch 38/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.4148e-05 - val_loss: 4.3882e-05
# Epoch 39/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.4503e-05 - val_loss: 2.6158e-05
# Epoch 40/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3340e-05 - val_loss: 5.4140e-05
# Epoch 41/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3492e-05 - val_loss: 9.4979e-05
# Epoch 42/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.5601e-05 - val_loss: 2.7404e-05
# Epoch 43/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3210e-05 - val_loss: 3.7374e-05
# Epoch 44/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.2023e-05 - val_loss: 3.0415e-05
# Epoch 45/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3743e-05 - val_loss: 4.3293e-05
# Epoch 46/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8925e-05 - val_loss: 5.1209e-05
# Epoch 47/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.9527e-05 - val_loss: 2.9036e-05
# Epoch 48/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8608e-05 - val_loss: 2.7006e-05
# Epoch 49/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.0035e-05 - val_loss: 2.8019e-05
# Epoch 50/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.1276e-05 - val_loss: 2.6132e-05
# Epoch 51/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.1762e-05 - val_loss: 5.1363e-05
# Epoch 52/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.0039e-05 - val_loss: 3.9444e-05
# Epoch 53/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.0184e-05 - val_loss: 3.1609e-05
# Epoch 54/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.1199e-05 - val_loss: 3.1479e-05
# Epoch 55/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3773e-05 - val_loss: 2.8211e-05
# Epoch 56/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.1423e-05 - val_loss: 2.8403e-05
# Epoch 57/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8826e-05 - val_loss: 7.2462e-05
# Epoch 58/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3093e-05 - val_loss: 3.6485e-05
# Epoch 59/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8806e-05 - val_loss: 3.0158e-05
# Epoch 60/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.3004e-05 - val_loss: 2.6320e-05
# Epoch 61/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7829e-05 - val_loss: 4.4367e-05
# Epoch 62/100
# 230/230 [==============================] - 18s 79ms/step - loss: 3.0486e-05 - val_loss: 2.9643e-05
# Epoch 63/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8831e-05 - val_loss: 2.5977e-05
# Epoch 64/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.0492e-05 - val_loss: 7.7885e-05
# Epoch 65/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.1179e-05 - val_loss: 4.2345e-05
# Epoch 66/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6731e-05 - val_loss: 2.9908e-05
# Epoch 67/100
# 230/230 [==============================] - 19s 81ms/step - loss: 3.0255e-05 - val_loss: 2.6685e-05
# Epoch 68/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.0097e-05 - val_loss: 2.8060e-05
# Epoch 69/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7356e-05 - val_loss: 5.7569e-05
# Epoch 70/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.7376e-05 - val_loss: 3.2358e-05
# Epoch 71/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6973e-05 - val_loss: 2.7571e-05
# Epoch 72/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.5752e-05 - val_loss: 3.4115e-05
# Epoch 73/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.2683e-05 - val_loss: 3.2758e-05
# Epoch 74/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7191e-05 - val_loss: 3.4832e-05
# Epoch 75/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.8977e-05 - val_loss: 3.3768e-05
# Epoch 76/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7634e-05 - val_loss: 8.8988e-05
# Epoch 77/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8424e-05 - val_loss: 2.6523e-05
# Epoch 78/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.7864e-05 - val_loss: 2.6891e-05
# Epoch 79/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8849e-05 - val_loss: 2.8851e-05
# Epoch 80/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7630e-05 - val_loss: 2.6225e-05
# Epoch 81/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.7846e-05 - val_loss: 2.9051e-05
# Epoch 82/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.7000e-05 - val_loss: 2.6812e-05
# Epoch 83/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.9659e-05 - val_loss: 3.0173e-05
# Epoch 84/100
# 230/230 [==============================] - 19s 80ms/step - loss: 2.8053e-05 - val_loss: 4.4260e-05
# Epoch 85/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8376e-05 - val_loss: 4.2186e-05
# Epoch 86/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.9056e-05 - val_loss: 3.1177e-05
# Epoch 87/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.5487e-05 - val_loss: 2.6708e-05
# Epoch 88/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.6038e-05 - val_loss: 2.6936e-05
# Epoch 89/100
# 230/230 [==============================] - 18s 80ms/step - loss: 3.0530e-05 - val_loss: 3.3973e-05
# Epoch 90/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6479e-05 - val_loss: 2.6905e-05
# Epoch 91/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.5625e-05 - val_loss: 3.6024e-05
# Epoch 92/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.4890e-05 - val_loss: 2.5879e-05
# Epoch 93/100
# 230/230 [==============================] - 19s 81ms/step - loss: 3.0279e-05 - val_loss: 3.0092e-05
# Epoch 94/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.8570e-05 - val_loss: 3.9411e-05
# Epoch 95/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.5273e-05 - val_loss: 2.6500e-05
# Epoch 96/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6689e-05 - val_loss: 3.8400e-05
# Epoch 97/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6827e-05 - val_loss: 4.8368e-05
# Epoch 98/100
# 230/230 [==============================] - 18s 80ms/step - loss: 2.6082e-05 - val_loss: 2.9490e-05
# Epoch 99/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.6759e-05 - val_loss: 3.9285e-05
# Epoch 100/100
# 230/230 [==============================] - 19s 81ms/step - loss: 2.5813e-05 - val_loss: 2.6503e-05
# 14638.995707078853
# 14844.858755227076
